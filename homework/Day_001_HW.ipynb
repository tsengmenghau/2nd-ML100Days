# %% [markdown]
# # 作業1
# ### 1. 你選的這組資料為何重要
# 我很想把機器學習學好，所以挑一個比較簡單的先著手，由簡入深
# Suicide Rates Overview 1985 to 2016
# 我會選這筆資料組的原因是因為資料好取得，檔案很小，而且是CSV檔案
#
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Kaggle平台獲得資料，Rusty提供，
# 由四個數據連結所蒐集
# 1United Nations Development Program. (2018). Human development index (HDI)
# 2World Bank. (2018). World development indicators: GDP (current US$) by country:1985 to 2016.
# 3[Szamil]. (2017). Suicide in the Twenty-First Century [dataset].
# 4World Health Organization. (2018). Suicide prevention.
# ### 3. 蒐集而來的資料型態為何
# CSV檔案 結構化:數值、表格
# country, year, sex, age group, count of suicides, population, suicide rate, country-year composite key, HDI for year, gdp_for_year, gdp_per_capita, generation (based on age grouping average).
# ### 4. 這組資料想解決的問題如何評估
# 想了解國民所得的高低、歲數、性別與自殺之間的相關性，想了解哪個族群比較容易自殺，最後由計算出的結果預防。

# %% [markdown]
# # 作業2
# ## 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ### 1. 核心問題為何
# 利潤為核心，扣掉成本才是真的。了解區域市場的供給與需求，擬定策略。了解區域大多是哪一類型的消費者，鎖定甚麼樣的消費者，還有競爭者分析。
#
# 目前核心問題首要先了解概況:當地環境、消費者、競爭者、本身的公司作為出發點探討
#
#
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 紀錄自己載客車隊的動線，從資料中找客車載客的起迄點，進一步了解當地哪些地點比較容易達成交易。
# 政府公開平台蒐集附近區域用地的性質(觀光、商用、住宅、娛樂)並與動線結合，了解旅次的目的，進一步了解客戶。
#
# ### 3. 蒐集而來的資料型態為何
# 結構化:數值、表格、經緯度。
# 非結構化:地址、目的。
# ### 4. 你要回答的問題，其如何評估
# 透過統計的方式找出之間的關聯性。

# %% [markdown]
# # 作業3
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=sum((y-yp)**2)/len(y)
    
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行

MAE = mean_absolute_error(y, y_hat)
MSE = mean_squared_error(y,y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 205.854
# The Mean absolute error is 10.971
